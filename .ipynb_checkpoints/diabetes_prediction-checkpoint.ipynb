# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
diab_data = pd.read_csv('diabetes.csv')

# %%
diab_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
diab_data.shape
# Out:
# (2000, 9)

# %%
diab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# Pregnancies                 2000 non-null int64
# Glucose                     2000 non-null int64
# BloodPressure               2000 non-null int64
# SkinThickness               2000 non-null int64
# Insulin                     2000 non-null int64
# BMI                         2000 non-null float64
# DiabetesPedigreeFunction    2000 non-null float64
# Age                         2000 non-null int64
# Outcome                     2000 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 140.7 KB

# %%
diab_data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
diab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# Pregnancies                 2000 non-null int64
# Glucose                     2000 non-null int64
# BloodPressure               2000 non-null int64
# SkinThickness               2000 non-null int64
# Insulin                     2000 non-null int64
# BMI                         2000 non-null float64
# DiabetesPedigreeFunction    2000 non-null float64
# Age                         2000 non-null int64
# Outcome                     2000 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 140.7 KB

# %%
sns.catplot(data=diab_data,x="Pregnancies",y="Outcome",kind="bar",ci=None,height = 7)

# %%
sns.catplot(data=diab_data,x="Glucose",y="Outcome",kind="bar",ci=None,height=10)

# %%
sns.catplot(data=diab_data,x="BloodPressure",y="Outcome",kind="bar",ci=None,height = 10)

# %%
sns.catplot(data=diab_data,x="SkinThickness",y="Outcome",kind="bar",ci=None)

# %%
g=sns.catplot(data=diab_data,x="Insulin",y="Outcome",kind="bar",ci=None)
g.fig.set_figheight(6)
g.fig.set_figwidth(50)

# %%
sns.catplot(data=diab_data,x="BMI",y="Outcome",kind="bar",ci=None)

# %%
sns.catplot(data=diab_data,x="DiabetesPedigreeFunction",y="Outcome",kind="bar",ci=None)

# %%
sns.catplot(data=diab_data,x="Age",y="Outcome",kind="bar",ci=None,height=10)

# %%
sns.heatmap(diab_data.corr())

# %%
sns.countplot(y=diab_data['Outcome'],palette='Set1')

# %%
sns.set(style="ticks")
sns.pairplot(diab_data, hue="Outcome")

# %%
df = diab_data

# %%
#box plot
sns.set(style="whitegrid")

sns.set(rc={'figure.figsize':(4,2)})
sns.boxplot(x=df['Pregnancies'])
plt.show()
sns.boxplot(x=df['Glucose'])
plt.show()
sns.boxplot(x=df['BloodPressure'])
plt.show()
sns.boxplot(x=df['SkinThickness'])
plt.show()
sns.boxplot(x=df['Insulin'])
plt.show()
sns.boxplot(x=df['BMI'])
plt.show()
sns.boxplot(x=df['DiabetesPedigreeFunction'])
plt.show()
sns.boxplot(x=df['Age'])
plt.show()

# %%
#outlier remove

Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

print("---Q1--- \n",Q1)
print("\n---Q3--- \n",Q3)
print("\n---IQR---\n",IQR)

#print((df < (Q1 - 1.5 * IQR))|(df > (Q3 + 1.5 * IQR)))
# Out:
# ---Q1---
#  Pregnancies                  1.000
# Glucose                     99.000
# BloodPressure               63.500
# SkinThickness                0.000
# Insulin                      0.000
# BMI                         27.375
# DiabetesPedigreeFunction     0.244
# Age                         24.000
# Outcome                      0.000
# Name: 0.25, dtype: float64
#
# ---Q3---
#  Pregnancies                   6.000
# Glucose                     141.000
# BloodPressure                80.000
# SkinThickness                32.000
# Insulin                     130.000
# BMI                          36.800
# DiabetesPedigreeFunction      0.624
# Age                          40.000
# Outcome                       1.000
# Name: 0.75, dtype: float64
#
# ---IQR---
#  Pregnancies                   5.000
# Glucose                      42.000
# BloodPressure                16.500
# SkinThickness                32.000
# Insulin                     130.000
# ...

# %%
#outlier remove
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape,df_out.shape
#more than 80 records deleted
# Out:
# ((2000, 9), (1652, 9))

# %% [markdown]
# # model building

# %%
#lets extract features and targets
X=df_out.drop(columns=['Outcome'])
y=df_out['Outcome']

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2)

# %%
train_X.shape,test_X.shape,train_y.shape,test_y.shape
# Out:
# ((1321, 8), (331, 8), (1321,), (331,))

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,make_scorer
from sklearn.model_selection import cross_validate

def tn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 0]
def tp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 1]

#cross validation purpose
scoring = {'accuracy': make_scorer(accuracy_score),'prec': 'precision'}
scoring = {'tp': make_scorer(tp), 'tn': make_scorer(tn),
           'fp': make_scorer(fp), 'fn': make_scorer(fn)}

def display_result(result):
    print("TP: ",result['test_tp'])
    print("TN: ",result['test_tn'])
    print("FN: ",result['test_fn'])
    print("FP: ",result['test_fp'])
    
    
model_data = pd.DataFrame()

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

acc=[]
roc=[]

clf=LogisticRegression()
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.7734138972809668 ROC 0.7043939393939394
# TP:  [21 23 21 23 17 26 18 24 21 21]
# TN:  [83 82 86 85 84 83 82 83 81 82]
# FN:  [21 19 21 19 25 16 23 17 20 20]
# FP:  [8 9 5 6 7 7 8 7 9 8]

# %%
#Support Vector Machine
from sklearn.svm import SVC

clf=SVC(kernel='linear')
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.7734138972809668 ROC 0.7043939393939394
# TP:  [23 23 21 24 18 26 19 24 21 22]
# TN:  [84 79 85 84 81 81 82 84 80 83]
# FN:  [19 19 21 18 24 16 22 17 20 19]
# FP:  [ 7 12  6  7 10  9  8  6 10  7]

# %%
#KNN

from sklearn.neighbors import KNeighborsClassifier

clf=KNeighborsClassifier(n_neighbors=3)
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.8821752265861027 ROC 0.8645454545454544
# TP:  [32 30 29 27 29 33 31 27 28 31]
# TN:  [79 76 84 84 83 83 81 80 78 79]
# FN:  [10 12 13 15 13  9 10 14 13 10]
# FP:  [12 15  7  7  8  7  9 10 12 11]

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier()
clf.fit(train_X,train_y)

y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.972809667673716 ROC 0.9635064935064934
# TP:  [38 39 37 39 36 39 41 40 39 36]
# TN:  [90 91 90 91 88 85 88 87 87 89]
# FN:  [4 3 5 3 6 3 0 1 2 5]
# FP:  [1 0 1 0 3 5 2 3 3 1]

# %%
#Naive Bayes Theorem
#import library
from sklearn.naive_bayes import GaussianNB

clf=GaussianNB()
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.7462235649546828 ROC 0.7104329004329004
# TP:  [22 27 27 25 23 33 23 27 23 26]
# TN:  [76 75 78 79 76 71 77 77 77 81]
# FN:  [20 15 15 17 19  9 18 14 18 15]
# FP:  [15 16 13 12 15 19 13 13 13  9]

# %%
#Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
clf=GradientBoostingClassifier(n_estimators=50,learning_rate=0.2)
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.8912386706948641 ROC 0.871038961038961
# TP:  [34 31 33 31 28 32 29 32 30 32]
# TN:  [86 90 84 88 84 81 85 86 87 84]
# FN:  [ 8 11  9 11 14 10 12  9 11  9]
# FP:  [5 1 7 3 7 9 5 4 3 6]

# %%
acc
# Out:
# [0.7734138972809668,
#  0.7734138972809668,
#  0.8821752265861027,
#  0.972809667673716,
#  0.7462235649546828,
#  0.8912386706948641]

# %%
model_data = pd.DataFrame()

x_series = ['Logistic Regression','SVM','KNN','Random Forest','Naivye Bayes','Gradient Boosting']
y_series = acc
model_data['x'] = x_series
model_data['y'] = acc

# %%
ax = sns.barplot(x='x',y='y',data=model_data)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.show()



#hence random forest will give more accuracy

# %% [markdown]
# # fine tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
    'n_estimators': [200,300,400,500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
# ...

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 300}

# %%
rfc1=RandomForestClassifier(random_state=42, max_features='log2', n_estimators= 300, max_depth=8, criterion='gini')

# %%
rfc1.fit(train_X, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=8, max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
pred=rfc1.predict(test_X)
print("Accuracy for Random Forest on CV data: ",accuracy_score(test_y,pred))
# Out:
# Accuracy for Random Forest on CV data:  0.9546827794561934

# %%
#from this we can see that random forest with the standard hyperparametes

# %% [markdown]
# # feature transformation to remove skewnesss and increase model performance

# %%
df_out.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 3            0      135             68             42      250  42.3
# 5            0      173             78             32      265  46.5
# 6            4       99             72             17        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 3                     0.365   24        1
# 5                     1.159   58        0
# 6                     0.294   28        0

# %%
df_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1652 entries, 0 to 1999
# Data columns (total 9 columns):
# Pregnancies                 1652 non-null int64
# Glucose                     1652 non-null int64
# BloodPressure               1652 non-null int64
# SkinThickness               1652 non-null int64
# Insulin                     1652 non-null int64
# BMI                         1652 non-null float64
# DiabetesPedigreeFunction    1652 non-null float64
# Age                         1652 non-null int64
# Outcome                     1652 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 129.1 KB

# %%
df_out['Pregnancies'].hist(bins=20)
#left skewed

# %%
df_out['preg_log'] = np.log(df_out['Pregnancies']+1)

# %%
df_out.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 3            0      135             68             42      250  42.3
# 5            0      173             78             32      265  46.5
# 6            4       99             72             17        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome   ins_log   dpf_log  preg_log
# 0                     0.127   47        1  0.000000  0.119559  1.098612
# 1                     0.233   23        0  4.836282  0.209450  0.000000
# 3                     0.365   24        1  5.525453  0.311154  0.000000
# 5                     1.159   58        0  5.583496  0.769645  0.000000
# 6                     0.294   28        0  0.000000  0.257738  1.609438

# %%
df_out['Glucose'].hist(bins=20)

# %%
df_out['BloodPressure'].hist(bins=20)

# %%
df_out['SkinThickness'].hist(bins=20)
#different kind of data

# %%
df_out['Insulin'].hist(bins=20)
#different kind of data

# %%
#Do log(x+1) transformation.This is the best way to avoid error created by log transformation and is widely used among data scientists.
df_out['ins_log'] = np.log(df_out['Insulin']+1)

# %%
df_out.head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2      138             62             35        0  33.6
# 1             0       84             82             31      125  38.2
# 3             0      135             68             42      250  42.3
# 5             0      173             78             32      265  46.5
# 6             4       99             72             17        0  25.6
# 8             2       83             65             28       66  36.8
# 9             2       89             90             30        0  33.5
# 10            4       99             68             38        0  32.8
# 11            4      125             70             18      122  28.9
# 14            5      110             68              0        0  26.0
#
#     DiabetesPedigreeFunction  Age  Outcome   ins_log
# 0                      0.127   47        1  0.000000
# 1                      0.233   23        0  4.836282
# ...

# %%
df_out['BMI'].hist(bins=20)

# %%
df_out['DiabetesPedigreeFunction'].hist(bins=20)

# %%
df_out['dpf_log'] = np.log(df_out['DiabetesPedigreeFunction']+1)

# %%
df_out.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 3            0      135             68             42      250  42.3
# 5            0      173             78             32      265  46.5
# 6            4       99             72             17        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome   ins_log   dpf_log
# 0                     0.127   47        1  0.000000  0.119559
# 1                     0.233   23        0  4.836282  0.209450
# 3                     0.365   24        1  5.525453  0.311154
# 5                     1.159   58        0  5.583496  0.769645
# 6                     0.294   28        0  0.000000  0.257738

# %% [markdown]
# # now lets build a random forest model with new features

# %%
df_out.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'ins_log',
#        'dpf_log', 'preg_log'],
#       dtype='object')

# %%
train_data = df_out[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
       'BMI', 'Age', 'Outcome', 'ins_log',
       'dpf_log','preg_log']]

# %%
X=train_data.drop(columns=['Outcome'])
y=train_data['Outcome']

# %%
#Splitting train test data 80 20 ratio
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2)

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier()
clf.fit(train_X,train_y)

y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()
# Out:
# Accuracy 0.9909365558912386 ROC 0.9861111111111112
# TP:  [37 39 40 39 35 32 38 35 37 38]
# TN:  [92 90 90 88 88 85 87 90 90 89]
# FN:  [4 2 1 2 6 9 3 6 3 2]
# FP:  [0 2 2 3 3 6 4 1 1 2]

# %%
#here roc and accuracy has increased from 96 to 98 and 97.28 to 99
